# %% [markdown]
# <h1><center>Sales Data Analysis</h1>

# %%
import pandas as pd

# %%
d_f_1=pd.read_csv("E:\\kaith_gaili\\practise_12_month_data\\SalesAnalysis\\Sales_Data\\Sales_April_2019.csv")

# %%
d_f_1.head(4)
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1      NaN                         NaN              NaN        NaN
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
#
#        Order Date                      Purchase Address
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 1             NaN                                   NaN
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001

# %%
d_f_2=pd.read_csv("E:\\kaith_gaili\\practise_12_month_data\\SalesAnalysis\\Sales_Data\\Sales_August_2019.csv")

# %%
d_f_2.head(4)
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   236670            Wired Headphones                2      11.99
# 1   236671  Bose SoundSport Headphones                1      99.99
# 2   236672                      iPhone                1      700.0
# 3   236673       AA Batteries (4-pack)                2       3.84
#
#        Order Date                   Purchase Address
# 0  08/31/19 22:21   359 Spruce St, Seattle, WA 98101
# 1  08/15/19 15:11     492 Ridge St, Dallas, TX 75001
# 2  08/06/19 14:40     149 7th St, Portland, OR 97035
# 3  08/29/19 20:59  631 2nd St, Los Angeles, CA 90001

# %%
d_f_3=pd.read_csv("E:\\kaith_gaili\\practise_12_month_data\\SalesAnalysis\\Sales_Data\\Sales_December_2019.csv")

# %%
d_f_4=pd.read_csv("E:\\kaith_gaili\\practise_12_month_data\\SalesAnalysis\\Sales_Data\\Sales_February_2019.csv")

# %%
d_f_5=pd.read_csv("E:\\kaith_gaili\\practise_12_month_data\\SalesAnalysis\\Sales_Data\\Sales_January_2019.csv")

# %%
d_f_6=pd.read_csv("E:\\kaith_gaili\\practise_12_month_data\\SalesAnalysis\\Sales_Data\\Sales_July_2019.csv")

# %%
d_f_7=pd.read_csv("E:\\kaith_gaili\\practise_12_month_data\\SalesAnalysis\\Sales_Data\\Sales_June_2019.csv")

# %%
d_f_8=pd.read_csv("E:\\kaith_gaili\\practise_12_month_data\\SalesAnalysis\\Sales_Data\\Sales_March_2019.csv")

# %%
d_f_9=pd.read_csv("E:\\kaith_gaili\\practise_12_month_data\\SalesAnalysis\\Sales_Data\\Sales_May_2019.csv")

# %%
d_f_10=pd.read_csv("E:\\kaith_gaili\\practise_12_month_data\\SalesAnalysis\\Sales_Data\\Sales_November_2019.csv")

# %%
d_f_11=pd.read_csv("E:\\kaith_gaili\\practise_12_month_data\\SalesAnalysis\\Sales_Data\\Sales_October_2019.csv")

# %%
d_f_12=pd.read_csv("E:\\kaith_gaili\\practise_12_month_data\\SalesAnalysis\\Sales_Data\\Sales_September_2019.csv")

# %%
data=pd.concat([d_f_1,d_f_2,d_f_3,d_f_4,d_f_5,d_f_6,d_f_7,d_f_8,d_f_9,d_f_10,d_f_11,d_f_12])

# %%
data.shape
# Out:
# (186850, 6)

# %%
data.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1      NaN                         NaN              NaN        NaN
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 1             NaN                                   NaN
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001

# %%
data.isnull().sum()
# Out:
# Order ID            545
# Product             545
# Quantity Ordered    545
# Price Each          545
# Order Date          545
# Purchase Address    545
# dtype: int64

# %%
data.dropna(subset=["Order Date"],inplace=True)

# %%
data.isnull().sum()
# Out:
# Order ID            0
# Product             0
# Quantity Ordered    0
# Price Each          0
# Order Date          0
# Purchase Address    0
# dtype: int64

# %%
data.dtypes
# Out:
# Order ID            object
# Product             object
# Quantity Ordered    object
# Price Each          object
# Order Date          object
# Purchase Address    object
# dtype: object

# %%
data["Order Date"]=pd.to_datetime(data["Order Date"],errors="coerce")

# %%
data.dtypes
# Out:
# Order ID                    object
# Product                     object
# Quantity Ordered            object
# Price Each                  object
# Order Date          datetime64[ns]
# Purchase Address            object
# dtype: object

# %%
data.shape
# Out:
# (186305, 6)

# %%
data["month"]=data["Order Date"].dt.month

# %%
data.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
# 5   176561            Wired Headphones                1      11.99
#
#            Order Date                      Purchase Address  month
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001    4.0
# 2 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215    4.0
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001    4.0
# 4 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001    4.0
# 5 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001    4.0

# %%
data["month"].unique()
# Out:
# array([ 4.,  5., nan,  8.,  9., 12.,  1.,  2.,  3.,  7.,  6., 11., 10.])

# %%
import numpy as np

# %%
data[data["month"]==4.0]
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       176558        USB-C Charging Cable                2      11.95
# 2       176559  Bose SoundSport Headphones                1      99.99
# 3       176560                Google Phone                1        600
# 4       176560            Wired Headphones                1      11.99
# 5       176561            Wired Headphones                1      11.99
# ...        ...                         ...              ...        ...
# 7519    169191            27in FHD Monitor                1     149.99
# 13161   174575       AA Batteries (4-pack)                1       3.84
# 13562   174959  Bose SoundSport Headphones                1      99.99
# 14404   175769  Bose SoundSport Headphones                1      99.99
# 14595   175951                    LG Dryer                1      600.0
#
#                Order Date                         Purchase Address  month
# ...

# %%
data["month"].value_counts()
# Out:
# 12.0    24984
# 10.0    20282
# 4.0     18279
# 11.0    17573
# 5.0     16566
# 3.0     15153
# 7.0     14293
# 6.0     13554
# 2.0     11975
# 8.0     11961
# 9.0     11621
# 1.0      9709
# Name: month, dtype: int64

# %%
data["Quantity Ordered"]=pd.to_numeric(data["Quantity Ordered"],errors="coerce")
data["Price Each"]=pd.to_numeric(data["Price Each"],errors="coerce")

# %%
data.dtypes
# Out:
# Order ID                    object
# Product                     object
# Quantity Ordered           float64
# Price Each                 float64
# Order Date          datetime64[ns]
# Purchase Address            object
# month                      float64
# dtype: object

# %%
data["sale"]=data["Quantity Ordered"] * data["Price Each"]

# %%
data.head(6)
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable               2.0       11.95
# 2   176559  Bose SoundSport Headphones               1.0       99.99
# 3   176560                Google Phone               1.0      600.00
# 4   176560            Wired Headphones               1.0       11.99
# 5   176561            Wired Headphones               1.0       11.99
# 6   176562        USB-C Charging Cable               1.0       11.95
#
#            Order Date                        Purchase Address  month    sale
# 0 2019-04-19 08:46:00            917 1st St, Dallas, TX 75001    4.0   23.90
# 2 2019-04-07 22:30:00       682 Chestnut St, Boston, MA 02215    4.0   99.99
# 3 2019-04-12 14:38:00    669 Spruce St, Los Angeles, CA 90001    4.0  600.00
# 4 2019-04-12 14:38:00    669 Spruce St, Los Angeles, CA 90001    4.0   11.99
# 5 2019-04-30 09:27:00       333 8th St, Los Angeles, CA 90001    4.0   11.99
# ...

# %%
data.isnull().sum()
# Out:
# Order ID              0
# Product               0
# Quantity Ordered    355
# Price Each          355
# Order Date          355
# Purchase Address      0
# month               355
# sale                355
# dtype: int64

# %%
data.dtypes
# Out:
# Order ID                    object
# Product                     object
# Quantity Ordered           float64
# Price Each                 float64
# Order Date          datetime64[ns]
# Purchase Address            object
# month                      float64
# sale                       float64
# dtype: object

# %% [markdown]
# ### Question 1: What was the best month for sale?How much was earned that month?

# %%
month_sale=data.groupby("month").mean()["sale"]

# %%
month_sale
# Out:
# month
# 1.0     187.687376
# 2.0     183.884962
# 3.0     185.250471
# 4.0     185.495390
# 5.0     190.305852
# 6.0     190.187565
# 7.0     185.249826
# 8.0     187.648849
# 9.0     180.497387
# 10.0    184.238580
# 11.0    182.074956
# 12.0    184.655913
# Name: sale, dtype: float64

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
months = range(1,13)
plt.bar(month_sale.index,month_sale.values)
plt.xticks(months);

# %%
month_sale1=data.groupby("month").sum()["sale"]
month_sale1
# Out:
# month
# 1.0     1.822257e+06
# 2.0     2.202022e+06
# 3.0     2.807100e+06
# 4.0     3.390670e+06
# 5.0     3.152607e+06
# 6.0     2.577802e+06
# 7.0     2.647776e+06
# 8.0     2.244468e+06
# 9.0     2.097560e+06
# 10.0    3.736727e+06
# 11.0    3.199603e+06
# 12.0    4.613443e+06
# Name: sale, dtype: float64

# %%
plt.bar(month_sale1.index,month_sale1.values)
plt.xticks(months);

# %%
a="917 1st St, Dallas, TX 75001"

# %%
a.split()
# Out:
# ['917', '1st', 'St,', 'Dallas,', 'TX', '75001']

# %%
a.split(",")
# Out:
# ['917 1st St', ' Dallas', ' TX 75001']

# %%
for x in a.split(","):
    print(x)
# Out:
# 917 1st St
#  Dallas
#  TX 75001

# %%
data.head(4)
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable               2.0       11.95
# 2   176559  Bose SoundSport Headphones               1.0       99.99
# 3   176560                Google Phone               1.0      600.00
# 4   176560            Wired Headphones               1.0       11.99
#
#            Order Date                      Purchase Address  month    sale
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001    4.0   23.90
# 2 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215    4.0   99.99
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001    4.0  600.00
# 4 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001    4.0   11.99

# %%
#this code doesn't work
#data["city"]=data["Purchase Address"].apply(lambda x : x.split(",")[1])

# %%
def city(x):
    if len(x.split(','))>1:
        return x.split(',')[1]
    else:
        return "missing"

# %%
data["city"]=data["Purchase Address"].apply(city)

# %%
data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable               2.0       11.95
# 2   176559  Bose SoundSport Headphones               1.0       99.99
# 3   176560                Google Phone               1.0      600.00
# 4   176560            Wired Headphones               1.0       11.99
# 5   176561            Wired Headphones               1.0       11.99
#
#            Order Date                      Purchase Address  month    sale  \
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001    4.0   23.90
# 2 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215    4.0   99.99
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001    4.0  600.00
# 4 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001    4.0   11.99
# 5 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001    4.0   11.99
#
#            city
# 0        Dallas
# 2        Boston
# 3   Los Angeles
# 4   Los Angeles
# ...

# %%
data[data["city"]=="missing"]
# Out:
#        Order ID  Product  Quantity Ordered  Price Each Order Date  \
# 519    Order ID  Product               NaN         NaN        NaT
# 1149   Order ID  Product               NaN         NaN        NaT
# 1155   Order ID  Product               NaN         NaN        NaT
# 2878   Order ID  Product               NaN         NaN        NaT
# 2893   Order ID  Product               NaN         NaN        NaT
# ...         ...      ...               ...         ...        ...
# 10000  Order ID  Product               NaN         NaN        NaT
# 10387  Order ID  Product               NaN         NaN        NaT
# 11399  Order ID  Product               NaN         NaN        NaT
# 11468  Order ID  Product               NaN         NaN        NaT
# 11574  Order ID  Product               NaN         NaN        NaT
#
#        Purchase Address  month  sale     city
# 519    Purchase Address    NaN   NaN  missing
# 1149   Purchase Address    NaN   NaN  missing
# ...

# %%
data.isnull().sum()
# Out:
# Order ID              0
# Product               0
# Quantity Ordered    355
# Price Each          355
# Order Date          355
# Purchase Address      0
# month               355
# sale                355
# city                  0
# dtype: int64

# %%
#data.dropna(subset=["Price Each"],inplace=True)

# %%
#data.isnull().sum()

# %%
data["city"].replace({"missing":"0"},inplace=True)

# %%
data[data["city"]=="missing"]
# Out:
# Empty DataFrame
# Columns: [Order ID, Product, Quantity Ordered, Price Each, Order Date, Purchase Address, month, sale, city]
# Index: []

# %%
data[data["city"]=="0"]
# Out:
#        Order ID  Product  Quantity Ordered  Price Each Order Date  \
# 519    Order ID  Product               NaN         NaN        NaT
# 1149   Order ID  Product               NaN         NaN        NaT
# 1155   Order ID  Product               NaN         NaN        NaT
# 2878   Order ID  Product               NaN         NaN        NaT
# 2893   Order ID  Product               NaN         NaN        NaT
# ...         ...      ...               ...         ...        ...
# 10000  Order ID  Product               NaN         NaN        NaT
# 10387  Order ID  Product               NaN         NaN        NaT
# 11399  Order ID  Product               NaN         NaN        NaT
# 11468  Order ID  Product               NaN         NaN        NaT
# 11574  Order ID  Product               NaN         NaN        NaT
#
#        Purchase Address  month  sale city
# 519    Purchase Address    NaN   NaN    0
# 1149   Purchase Address    NaN   NaN    0
# 1155   Purchase Address    NaN   NaN    0
# ...

# %%
data.isnull().sum()
# Out:
# Order ID              0
# Product               0
# Quantity Ordered    355
# Price Each          355
# Order Date          355
# Purchase Address      0
# month               355
# sale                355
# city                  0
# dtype: int64

# %%
data=data[data["city"]!="0"]

# %% [markdown]
# ### Question 2: what city had the highest number of sell?

# %%
city_sale=data.groupby("city").sum()["sale"]
city_sale
# Out:
# city
#  Atlanta          2.795499e+06
#  Austin           1.819582e+06
#  Boston           3.661642e+06
#  Dallas           2.767975e+06
#  Los Angeles      5.452571e+06
#  New York City    4.664317e+06
#  Portland         2.320491e+06
#  San Francisco    8.262204e+06
#  Seattle          2.747755e+06
# Name: sale, dtype: float64

# %%
plt.figure(figsize=(12,6))
plt.xticks(rotation=90,size=10)
plt.bar(city_sale.index,city_sale.values);

# %%
plt.figure(figsize=(6,6))
plt.barh(city_sale.index,city_sale.values);

# %% [markdown]
# ### Question 3: what time should we display advertisements to maximize likelihood of customer's buying product?

# %%
data.head(4)
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable               2.0       11.95
# 2   176559  Bose SoundSport Headphones               1.0       99.99
# 3   176560                Google Phone               1.0      600.00
# 4   176560            Wired Headphones               1.0       11.99
#
#            Order Date                      Purchase Address  month    sale  \
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001    4.0   23.90
# 2 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215    4.0   99.99
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001    4.0  600.00
# 4 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001    4.0   11.99
#
#            city
# 0        Dallas
# 2        Boston
# 3   Los Angeles
# 4   Los Angeles

# %%
data["hour"]=data["Order Date"].dt.hour

# %%
data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable               2.0       11.95
# 2   176559  Bose SoundSport Headphones               1.0       99.99
# 3   176560                Google Phone               1.0      600.00
# 4   176560            Wired Headphones               1.0       11.99
# 5   176561            Wired Headphones               1.0       11.99
#
#            Order Date                      Purchase Address  month    sale  \
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001    4.0   23.90
# 2 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215    4.0   99.99
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001    4.0  600.00
# 4 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001    4.0   11.99
# 5 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001    4.0   11.99
#
#            city  hour
# 0        Dallas     8
# 2        Boston    22
# 3   Los Angeles    14
# ...

# %%
advertise=data["hour"].value_counts()
advertise
# Out:
# 19    12905
# 12    12587
# 11    12411
# 18    12280
# 20    12228
# 13    12129
# 14    10984
# 10    10944
# 21    10921
# 17    10899
# 16    10384
# 15    10175
# 22     8822
# 9      8748
# 23     6275
# 8      6256
# 7      4011
# 0      3910
# 6      2482
# 1      2350
# 5      1321
# 2      1243
# 4       854
# 3       831
# Name: hour, dtype: int64

# %%
ai=advertise.index

plt.figure(figsize=(12,6))
plt.bar(ai,advertise.values)
plt.xlabel("Hour",size=20)
plt.ylabel("Number of Order",size=20)
plt.xticks(ai);

# %% [markdown]
# #### My recommendation is around 12am (12) or 7pm (19)

# %% [markdown]
# ### Question 4: What products are most often sold together?

# %%
data.head(4)
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable               2.0       11.95
# 2   176559  Bose SoundSport Headphones               1.0       99.99
# 3   176560                Google Phone               1.0      600.00
# 4   176560            Wired Headphones               1.0       11.99
#
#            Order Date                      Purchase Address  month    sale  \
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001    4.0   23.90
# 2 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215    4.0   99.99
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001    4.0  600.00
# 4 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001    4.0   11.99
#
#            city  hour
# 0        Dallas     8
# 2        Boston    22
# 3   Los Angeles    14
# 4   Los Angeles    14

# %%
df=data[data["Order ID"].duplicated(keep=False)]
df
# Out:
#       Order ID                     Product  Quantity Ordered  Price Each  \
# 3       176560                Google Phone               1.0      600.00
# 4       176560            Wired Headphones               1.0       11.99
# 18      176574                Google Phone               1.0      600.00
# 19      176574        USB-C Charging Cable               1.0       11.95
# 30      176585  Bose SoundSport Headphones               1.0       99.99
# ...        ...                         ...               ...         ...
# 11628   259303       AA Batteries (4-pack)               1.0        3.84
# 11639   259314            Wired Headphones               1.0       11.99
# 11640   259314      AAA Batteries (4-pack)               2.0        2.99
# 11677   259350                Google Phone               1.0      600.00
# 11678   259350        USB-C Charging Cable               1.0       11.95
#
#                Order Date                       Purchase Address  month  \
# ...

# %%
df["grouped"]=df.groupby("Order ID")["Product"].transform(lambda x : ','.join(x))
# Out:
# <ipython-input-72-71e5c73df421>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["grouped"]=df.groupby("Order ID")["Product"].transform(lambda x : ','.join(x))

# %%
df.head(6)
# Out:
#    Order ID                     Product  Quantity Ordered  Price Each  \
# 3    176560                Google Phone               1.0      600.00
# 4    176560            Wired Headphones               1.0       11.99
# 18   176574                Google Phone               1.0      600.00
# 19   176574        USB-C Charging Cable               1.0       11.95
# 30   176585  Bose SoundSport Headphones               1.0       99.99
# 31   176585  Bose SoundSport Headphones               1.0       99.99
#
#             Order Date                      Purchase Address  month    sale  \
# 3  2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001    4.0  600.00
# 4  2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001    4.0   11.99
# 18 2019-04-03 19:42:00     20 Hill St, Los Angeles, CA 90001    4.0  600.00
# 19 2019-04-03 19:42:00     20 Hill St, Los Angeles, CA 90001    4.0   11.95
# 30 2019-04-07 11:31:00     823 Highland St, Boston, MA 02215    4.0   99.99
# ...

# %%
df=df[["Order ID","grouped"]].drop_duplicates()
df
# Out:
#       Order ID                                            grouped
# 3       176560                      Google Phone,Wired Headphones
# 18      176574                  Google Phone,USB-C Charging Cable
# 30      176585  Bose SoundSport Headphones,Bose SoundSport Hea...
# 32      176586                AAA Batteries (4-pack),Google Phone
# 119     176672      Lightning Charging Cable,USB-C Charging Cable
# ...        ...                                                ...
# 11617   259296  Apple Airpods Headphones,Apple Airpods Headphones
# 11619   259297  iPhone,Lightning Charging Cable,Lightning Char...
# 11627   259303       34in Ultrawide Monitor,AA Batteries (4-pack)
# 11639   259314            Wired Headphones,AAA Batteries (4-pack)
# 11677   259350                  Google Phone,USB-C Charging Cable
#
# [7136 rows x 2 columns]

# %% [markdown]
# import necessary module

# %%
from itertools import combinations
from collections import Counter

# %%
count=Counter()
for row in df["grouped"]:
    row_list=row.split(',')
    count.update(Counter(combinations(row_list,2)))
print(count)
# Out:
# Counter({('iPhone', 'Lightning Charging Cable'): 1005, ('Google Phone', 'USB-C Charging Cable'): 987, ('iPhone', 'Wired Headphones'): 447, ('Google Phone', 'Wired Headphones'): 414, ('Vareebadd Phone', 'USB-C Charging Cable'): 361, ('iPhone', 'Apple Airpods Headphones'): 360, ('Google Phone', 'Bose SoundSport Headphones'): 220, ('USB-C Charging Cable', 'Wired Headphones'): 160, ('Vareebadd Phone', 'Wired Headphones'): 143, ('Lightning Charging Cable', 'Wired Headphones'): 92, ('Lightning Charging Cable', 'Apple Airpods Headphones'): 81, ('Vareebadd Phone', 'Bose SoundSport Headphones'): 80, ('USB-C Charging Cable', 'Bose SoundSport Headphones'): 77, ('Apple Airpods Headphones', 'Wired Headphones'): 69, ('Lightning Charging Cable', 'USB-C Charging Cable'): 58, ('Lightning Charging Cable', 'AA Batteries (4-pack)'): 55, ('Lightning Charging Cable', 'Lightning Charging Cable'): 54, ('Bose SoundSport Headphones', 'Wired Headphones'): 53, ('AA Batteries (4-pack)', 'Lightning Charging Cable
# ...

# %%
count=Counter()
for row in df["grouped"]:
    row_list=row.split(',')
    count.update(Counter(combinations(row_list,2)))
for x,y in count.most_common(10):
    print(x,y)
# Out:
# ('iPhone', 'Lightning Charging Cable') 1005
# ('Google Phone', 'USB-C Charging Cable') 987
# ('iPhone', 'Wired Headphones') 447
# ('Google Phone', 'Wired Headphones') 414
# ('Vareebadd Phone', 'USB-C Charging Cable') 361
# ('iPhone', 'Apple Airpods Headphones') 360
# ('Google Phone', 'Bose SoundSport Headphones') 220
# ('USB-C Charging Cable', 'Wired Headphones') 160
# ('Vareebadd Phone', 'Wired Headphones') 143
# ('Lightning Charging Cable', 'Wired Headphones') 92

# %% [markdown]
# ### most three products are sold together

# %%
count=Counter()
for row in df["grouped"]:
    row_list=row.split(',')
    count.update(Counter(combinations(row_list,3)))
for x,y in count.most_common(10):
    print(x,y)
# Out:
# ('Google Phone', 'USB-C Charging Cable', 'Wired Headphones') 87
# ('iPhone', 'Lightning Charging Cable', 'Wired Headphones') 62
# ('iPhone', 'Lightning Charging Cable', 'Apple Airpods Headphones') 47
# ('Google Phone', 'USB-C Charging Cable', 'Bose SoundSport Headphones') 35
# ('Vareebadd Phone', 'USB-C Charging Cable', 'Wired Headphones') 33
# ('iPhone', 'Apple Airpods Headphones', 'Wired Headphones') 27
# ('Google Phone', 'Bose SoundSport Headphones', 'Wired Headphones') 24
# ('Vareebadd Phone', 'USB-C Charging Cable', 'Bose SoundSport Headphones') 16
# ('USB-C Charging Cable', 'Bose SoundSport Headphones', 'Wired Headphones') 5
# ('Vareebadd Phone', 'Bose SoundSport Headphones', 'Wired Headphones') 5

# %% [markdown]
# ### Question 5: What product sold the most?Why do you think it sold the most?

# %%
data.head(4)
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable               2.0       11.95
# 2   176559  Bose SoundSport Headphones               1.0       99.99
# 3   176560                Google Phone               1.0      600.00
# 4   176560            Wired Headphones               1.0       11.99
#
#            Order Date                      Purchase Address  month    sale  \
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001    4.0   23.90
# 2 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215    4.0   99.99
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001    4.0  600.00
# 4 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001    4.0   11.99
#
#            city  hour
# 0        Dallas     8
# 2        Boston    22
# 3   Los Angeles    14
# 4   Los Angeles    14

# %%
quantity_order=data.groupby(["Product"]).sum()["Quantity Ordered"]
quantity_order
# Out:
# Product
# 20in Monitor                   4129.0
# 27in 4K Gaming Monitor         6244.0
# 27in FHD Monitor               7550.0
# 34in Ultrawide Monitor         6199.0
# AA Batteries (4-pack)         27635.0
# AAA Batteries (4-pack)        31017.0
# Apple Airpods Headphones      15661.0
# Bose SoundSport Headphones    13457.0
# Flatscreen TV                  4819.0
# Google Phone                   5532.0
# LG Dryer                        646.0
# LG Washing Machine              666.0
# Lightning Charging Cable      23217.0
# Macbook Pro Laptop             4728.0
# ThinkPad Laptop                4130.0
# USB-C Charging Cable          23975.0
# Vareebadd Phone                2068.0
# Wired Headphones              20557.0
# iPhone                         6849.0
# Name: Quantity Ordered, dtype: float64

# %%
plt.figure(figsize=(12,6))
plt.bar(quantity_order.index,quantity_order.values)
plt.xticks(rotation="vertical",size=15);

# %%
price=data.groupby("Product").mean()["Price Each"]
price
# Out:
# Product
# 20in Monitor                   109.99
# 27in 4K Gaming Monitor         389.99
# 27in FHD Monitor               149.99
# 34in Ultrawide Monitor         379.99
# AA Batteries (4-pack)            3.84
# AAA Batteries (4-pack)           2.99
# Apple Airpods Headphones       150.00
# Bose SoundSport Headphones      99.99
# Flatscreen TV                  300.00
# Google Phone                   600.00
# LG Dryer                       600.00
# LG Washing Machine             600.00
# Lightning Charging Cable        14.95
# Macbook Pro Laptop            1700.00
# ThinkPad Laptop                999.99
# USB-C Charging Cable            11.95
# Vareebadd Phone                400.00
# Wired Headphones                11.99
# iPhone                         700.00
# Name: Price Each, dtype: float64

# %%
fig,ax1=plt.subplots(figsize=(12,6))
ax2=ax1.twinx()
ax1.bar(quantity_order.index,quantity_order.values)
ax2.plot(price.index,price.values,color="r")
ax1.set_xlabel("Product Name")
ax1.set_ylabel("Order Quantity")
ax2.set_ylabel("Average Price ($)")
ax1.set_xticklabels(price.index,rotation="vertical",size=12);

# %% [markdown]
# <h1><center>The End<h1\>
